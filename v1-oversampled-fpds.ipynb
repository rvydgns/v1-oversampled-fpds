# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17807, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 17807 (delta 9), reused 4 (delta 4), pack-reused 17788 (from 2)
# Receiving objects: 100% (17807/17807), 16.98 MiB | 21.10 MiB/s, done.
# Resolving deltas: 100% (12141/12141), done.
# /kaggle/working/yolov5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.3 MB/s eta 0:00:0000:01

# %%
# !find "$P" -maxdepth 2 -name "*.yaml" -print
# !cat "$P/data.yaml"
# Out:
# /kaggle/input/oversampled-fpds/data.yaml
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 3
# names: ['fallen', 'sitting', 'standing']
#
# roboflow:
#   workspace: rescue-robot-datasets
#   project: oversampled-v1-fpds-mynsa
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/rescue-robot-datasets/oversampled-v1-fpds-mynsa/dataset/1

# %%
# %%writefile /kaggle/working/data_kaggle.yaml
# train: /kaggle/input/oversampled-fpds/train/images
# val: /kaggle/input/oversampled-fpds/valid/images
# test: /kaggle/input/oversampled-fpds/test/images
#
# nc: 3
# names: ['fallen', 'sitting', 'standing']
# Out:
# Writing /kaggle/working/data_kaggle.yaml

# %%
# !python train.py \
  --img 640 \
  --batch 32 \
  --epochs 100 \
  --data /kaggle/working/data_kaggle.yaml \
  --weights yolov5n.pt \
  --name fpds_yolov5n \
  --cache
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2026-02-09 11:34:01.181529: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770636841.394907     149 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770636841.456257     149 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770636841.961517     149 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770636841.961586     149 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770636841.961593     149 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770636841.961600     149 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# train: weights=yolov5n.pt, cfg=, data=/kaggle/working/data_kaggle.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=fpds_yolov5n, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-459-gdd2e2574 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 27.6MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5n.pt to yolov5n.pt...
# 100%|██████████████████████████████████████| 3.87M/3.87M [00:00<00:00, 87.4MB/s]
#
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
#   1                -1  1      4672  models.common.Conv                      [16, 32, 3, 2]
#   2                -1  1      4800  models.common.C3                        [32, 32, 1]
#   3                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   4                -1  2     29184  models.common.C3                        [64, 64, 2]
#   5                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   6                -1  3    156928  models.common.C3                        [128, 128, 3]
#   7                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   8                -1  1    296448  models.common.C3                        [256, 256, 1]
#   9                -1  1    164608  models.common.SPPF                      [256, 256, 5]
#  10                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  14                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     22912  models.common.C3                        [128, 64, 1, False]
#  18                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1     74496  models.common.C3                        [128, 128, 1, False]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  24      [17, 20, 23]  1     10824  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [64, 128, 256]]
# Model summary: 214 layers, 1767976 parameters, 1767976 gradients, 4.2 GFLOPs
#
# Transferred 343/349 items from yolov5n.pt
# /kaggle/working/yolov5/models/common.py:899: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /kaggle/working/yolov5/models/common.py:899: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# WARNING ⚠️ DP not recommended, use torch.distributed.run for best DDP Multi-GPU results.
# See Multi-GPU Tutorial at https://docs.ultralytics.com/yolov5/tutorials/multi_gpu_training to get started.
# albumentations: 1 validation error for InitSchema
# size
#   Field required [type=missing, input_value={'scale': (0.8, 1.0), 'ra...: None, 'strict': False}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# train: Scanning /kaggle/input/oversampled-fpds/train/labels... 4019 images, 237
# train: WARNING ⚠️ Cache directory /kaggle/input/oversampled-fpds/train is not writeable: [Errno 30] Read-only file system: '/kaggle/input/oversampled-fpds/train/labels.cache.npy'
# train: Caching images (3.4GB ram): 100%|██████████| 4019/4019 [00:09<00:00, 407.
# val: Scanning /kaggle/input/oversampled-fpds/valid/labels... 1184 images, 40 bac
# val: WARNING ⚠️ Cache directory /kaggle/input/oversampled-fpds/valid is not writeable: [Errno 30] Read-only file system: '/kaggle/input/oversampled-fpds/valid/labels.cache.npy'
# val: Caching images (1.0GB ram): 100%|██████████| 1184/1184 [00:03<00:00, 297.30
#
# AutoAnchor: 3.74 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/fpds_yolov5n/labels.jpg...
# /kaggle/working/yolov5/train.py:357: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/fpds_yolov5n
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/126 [00:00<?, ?it/s]/kaggle/working/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99       1.8G     0.1309    0.02871    0.04093         68        640:  /kaggle/working/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      1.86G     0.1308    0.02844    0.04106         71        640:  /kaggle/working/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      2.02G     0.1316    0.02782    0.03975         59        640:  /kaggle/working/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      2.02G     0.1297    0.02781    0.04003         70        640:  /kaggle/working/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      2.02G     0.1291    0.02788    0.04071         82        640:  /kaggle/working/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      2.02G     0.1292    0.02776    0.04028         76        640:  /kaggle/working/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      2.02G    0.07522    0.02322    0.02866         46        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       1184       1318      0.585      0.681      0.641      0.269
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/99      2.76G    0.05254    0.01544   0.009755         38        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       1184       1318      0.671      0.779      0.727      0.361
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/99      2.76G    0.04973    0.01459   0.007832         39        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       1184       1318      0.683      0.693      0.707      0.314
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/99      2.76G    0.04632    0.01465   0.008255         39        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       1184       1318      0.773      0.734      0.783      0.358
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/99      2.76G    0.04433    0.01443   0.006688         39        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       1184       1318      0.717        0.5       0.61      0.275
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/99      2.76G    0.04097    0.01418   0.006466         48        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       1184       1318      0.873      0.828      0.894      0.474
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/99      2.76G    0.03919    0.01389    0.00581         49        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       1184       1318      0.875      0.856      0.918       0.52
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/99      2.76G    0.03805    0.01352   0.005293         41        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       1184       1318      0